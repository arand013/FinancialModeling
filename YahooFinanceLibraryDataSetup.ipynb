# %% [markdown]
# <a href="https://colab.research.google.com/github/arand013/FinancialModeling/blob/main/YahooFinanceLibraryDataSetup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
# !pip install yfinance

# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import yfinance as yf

# %%
symbol = 'T'
ticker = yf.Ticker(symbol)
data = yf.download("T", period="24mo")
pd.Series(ticker.info).head(20)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# address1                                            208 South Akard Street
# city                                                                Dallas
# state                                                                   TX
# zip                                                                  75202
# country                                                      United States
# phone                                                         210 821 4105
# website                                                https://www.att.com
# industry                                                  Telecom Services
# industryKey                                               telecom-services
# industryDisp                                              Telecom Services
# sector                                              Communication Services
# sectorKey                                           communication-services
# ...

# %%
print(data)
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2022-05-16  19.930000  20.379999  19.680000  20.280001  17.838421  40027000
# 2022-05-17  20.400000  20.670000  20.240000  20.570000  18.093504  42938400
# 2022-05-18  20.510000  20.629999  20.129999  20.230000  17.794439  43342800
# 2022-05-19  19.920000  20.340000  19.910000  20.209999  17.776848  41588100
# 2022-05-20  20.209999  20.420000  20.090000  20.400000  17.943974  47415800
# ...               ...        ...        ...        ...        ...       ...
# 2024-05-09  17.100000  17.190001  17.040001  17.180000  17.180000  22547700
# 2024-05-10  17.200001  17.219999  17.120001  17.170000  17.170000  19229600
# 2024-05-13  17.180000  17.340000  17.150000  17.260000  17.260000  28014800
# 2024-05-14  17.280001  17.340000  17.219999  17.299999  17.299999  23545300
# 2024-05-15  17.350000  17.440001  17.180000  17.330000  17.330000  30842000
#
# [503 rows x 6 columns]

# %%
data = ticker.history(period='5d',
                      interval='1m',
                      start=None,
                      end=None,
                      actions=True,
                      auto_adjust=True,
                      back_adjust=False)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1949 entries, 2024-05-09 09:30:00-04:00 to 2024-05-15 15:59:00-04:00
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Open          1949 non-null   float64
#  1   High          1949 non-null   float64
#  2   Low           1949 non-null   float64
#  3   Close         1949 non-null   float64
#  4   Volume        1949 non-null   int64
#  5   Dividends     1949 non-null   float64
#  6   Stock Splits  1949 non-null   float64
# dtypes: float64(6), int64(1)
# memory usage: 121.8 KB

# %%
data = yf.download

# %%
# show actions (dividends, splits)
ticker.actions
# Out:
# Empty DataFrame
# Columns: [Dividends, Stock Splits]
# Index: []

# %%
ticker.dividends
# Out:
# Series([], Name: Dividends, dtype: float64)

# %%
ticker.splits
# Out:
# Series([], Name: Stock Splits, dtype: float64)

# %%
#  Annual and Quarterly Financial Statement Summary
ticker.financials
# Out:
#                                                         2023-12-31  \
# Tax Effect Of Unusual Items                           -254109000.0
# Tax Rate For Calcs                                           0.213
# Normalized EBITDA                                    46522000000.0
# Total Unusual Items                                  -1193000000.0
# Total Unusual Items Excluding Goodwill               -1193000000.0
# Net Income From Continuing Operation Net Minori...   14400000000.0
# Reconciled Depreciation                              18777000000.0
# Reconciled Cost Of Revenue                           50123000000.0
# EBITDA                                               45329000000.0
# EBIT                                                 26552000000.0
# Net Interest Income                                  -6704000000.0
# Interest Expense                                      6704000000.0
# Normalized Income                                    15338891000.0
# ...

# %%
ticker.quarterly_financials
# Out:
#                                                        2024-03-31  \
# Tax Effect Of Unusual Items                           -36570000.0
# Tax Rate For Calcs                                           0.23
# Normalized EBITDA                                   11799000000.0
# Total Unusual Items                                  -159000000.0
# Total Unusual Items Excluding Goodwill               -159000000.0
# Net Income From Continuing Operation Net Minori...   3445000000.0
# Reconciled Depreciation                              5047000000.0
# Reconciled Cost Of Revenue                          11954000000.0
# EBITDA                                              11640000000.0
# EBIT                                                 6593000000.0
# Net Interest Income                                 -1724000000.0
# Interest Expense                                     1724000000.0
# Normalized Income                                    3567430000.0
# ...

# %%
ticker.balance_sheet
# Out:
#                                                       2023-12-31  \
# Treasury Shares Number                               470685237.0
# Preferred Shares Number                              118000000.0
# Ordinary Shares Number                              7150063361.0
# Share Issued                                        7620748598.0
# Net Debt                                          130609000000.0
# ...                                                          ...
# Gross Accounts Receivable                          10788000000.0
# Cash Cash Equivalents And Short Term Investments    6722000000.0
# Cash And Cash Equivalents                           6722000000.0
# Cash Equivalents                                    5354000000.0
# Cash Financial                                      1368000000.0
#
#                                                       2022-12-31  \
# Treasury Shares Number                               493156816.0
# ...

# %%
ticker.quarterly_balance_sheet
# Out:
#                                                       2024-03-31  \
# Treasury Shares Number                               450713156.0
# Preferred Shares Number                              138000000.0
# Ordinary Shares Number                              7170035442.0
# Share Issued                                        7620748598.0
# Net Debt                                          129244000000.0
# ...                                                          ...
# Gross Accounts Receivable                          10040000000.0
# Cash Cash Equivalents And Short Term Investments    3520000000.0
# Cash And Cash Equivalents                           3520000000.0
# Cash Equivalents                                    2318000000.0
# Cash Financial                                      1202000000.0
#
#                                                       2023-12-31  \
# Treasury Shares Number                               470685237.0
# ...

# %% [markdown]
# ###  Annual and Quarterly Cashflow Statement

# %%
ticker.cashflow
# Out:
#                                             2023-12-31     2022-12-31  \
# Free Cash Flow                           20461000000.0  12397000000.0
# Repurchase Of Capital Stock               -194000000.0   -890000000.0
# Repayment Of Debt                       -16503000000.0 -45193000000.0
# Issuance Of Debt                         15410000000.0   6934000000.0
# Issuance Of Capital Stock                    3000000.0     28000000.0
# ...                                                ...            ...
# Operating Gains Losses                    -517000000.0  -4855000000.0
# Pension And Employee Benefit Expense      -958000000.0  -5236000000.0
# Earnings Losses From Equity Investments            NaN            NaN
# Gain Loss On Investment Securities         441000000.0    381000000.0
# Net Income From Continuing Operations    15623000000.0  -6874000000.0
#
#                                             2021-12-31     2020-12-31
# ...

# %%
ticker.quarterly_cashflow
# Out:
#                                                   2024-03-31     2023-12-31  \
# Free Cash Flow                                  3789000000.0   6777000000.0
# Repurchase Of Capital Stock                     -157000000.0     -4000000.0
# Repayment Of Debt                              -6681000000.0  -2591000000.0
# Issuance Of Debt                                2424000000.0    371000000.0
# Issuance Of Capital Stock                                0.0            0.0
# Capital Expenditure                            -3758000000.0  -4601000000.0
# End Cash Position                               3604000000.0   6833000000.0
# Beginning Cash Position                         6833000000.0   7659000000.0
# Changes In Cash                                -3229000000.0   -826000000.0
# Financing Cash Flow                            -7815000000.0  -6330000000.0
# Cash From Discontinued Financing Activities              NaN            0.0
# ...

# %%
ticker.sustainability
# Out:
# ---------------------------------------------------------------------------
# YFNotImplementedError                     Traceback (most recent call last)
# <ipython-input-51-1f0d3cf3013e> in <cell line: 1>()
# ----> 1 ticker.sustainability
#
# /usr/local/lib/python3.10/dist-packages/yfinance/ticker.py in sustainability(self)
#     252     @property
#     253     def sustainability(self) -> _pd.DataFrame:
# --> 254         return self.get_sustainability()
#     255
#     256     @property
#
# /usr/local/lib/python3.10/dist-packages/yfinance/base.py in get_sustainability(self, proxy, as_dict)
#     235     def get_sustainability(self, proxy=None, as_dict=False):
#     236         self._quote.proxy = proxy or self.proxy
# --> 237         data = self._quote.sustainability
#     238         if as_dict:
#     239             return data.to_dict()
#
# /usr/local/lib/python3.10/dist-packages/yfinance/scrapers/quote.py in sustainability(self)
# ...

# %% [markdown]
# # Analyst Recommendations

# %%
ticker.recommendations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   period      4 non-null      object
#  1   strongBuy   4 non-null      int64
#  2   buy         4 non-null      int64
#  3   hold        4 non-null      int64
#  4   sell        4 non-null      int64
#  5   strongSell  4 non-null      int64
# dtypes: int64(5), object(1)
# memory usage: 320.0+ bytes

# %%
ticker.recommendations.tail(10)
# Out:
#   period  strongBuy  buy  hold  sell  strongSell
# 0     0m          6    3    20     0           1
# 1    -1m          5    8    11     3           0
# 2    -2m          5    8    11     3           0
# 3    -3m          4    9    13     4           0

# %% [markdown]
# # Calendar Upcoming events

# %%
ticker.calendar
# Out:
# {'Dividend Date': datetime.date(2024, 5, 1),
#  'Ex-Dividend Date': datetime.date(2024, 4, 9),
#  'Earnings Date': [datetime.date(2024, 7, 24), datetime.date(2024, 7, 29)],
#  'Earnings High': 0.57,
#  'Earnings Low': 0.47,
#  'Earnings Average': 0.52,
#  'Revenue High': 30462000000,
#  'Revenue Low': 29437000000,
#  'Revenue Average': 30030200000}

# %% [markdown]
# #  Option Expiration Dates

# %%
ticker.options
# Out:
# ('2024-05-17',
#  '2024-05-24',
#  '2024-05-31',
#  '2024-06-07',
#  '2024-06-14',
#  '2024-06-21',
#  '2024-06-28',
#  '2024-07-19',
#  '2024-08-16',
#  '2024-09-20',
#  '2024-10-18',
#  '2024-11-15',
#  '2024-12-20',
#  '2025-01-17',
#  '2025-03-21',
#  '2025-06-20',
#  '2025-12-19',
#  '2026-01-16')

# %%
expiration = ticker.options[1]

# %%
options = ticker.option_chain(expiration)

# %%
options.calls.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   contractSymbol     40 non-null     object
#  1   lastTradeDate      40 non-null     datetime64[ns, UTC]
#  2   strike             40 non-null     float64
#  3   lastPrice          40 non-null     float64
#  4   bid                40 non-null     float64
#  5   ask                40 non-null     float64
#  6   change             40 non-null     float64
#  7   percentChange      40 non-null     float64
#  8   volume             38 non-null     float64
#  9   openInterest       40 non-null     int64
#  10  impliedVolatility  40 non-null     float64
#  11  inTheMoney         40 non-null     bool
#  12  contractSize       40 non-null     object
#  13  currency           40 non-null     object
# dtypes: bool(1), datetime64[ns, UTC](1), float64(8), int64(1), object(3)
# ...

# %%
options.calls.head()
# Out:
#         contractSymbol             lastTradeDate  strike  lastPrice    bid  \
# 0  GOOG240524C00080000 2024-05-15 19:45:40+00:00    80.0      93.85  92.30
# 1  GOOG240524C00085000 2024-04-26 17:44:57+00:00    85.0      89.06  87.20
# 2  GOOG240524C00090000 2024-05-13 19:53:44+00:00    90.0      80.60  82.35
# 3  GOOG240524C00095000 2024-05-15 16:29:17+00:00    95.0      77.80  77.35
# 4  GOOG240524C00100000 2024-05-09 15:06:49+00:00   100.0      71.07  72.20
#
#      ask    change  percentChange  volume  openInterest  impliedVolatility  \
# 0  94.95  6.699997       7.687891     1.0             6           2.967776
# 1  89.95  0.000000       0.000000     6.0             6           2.762698
# 2  84.95  0.000000       0.000000     5.0             5           2.569340
# 3  80.00  2.420006       3.210408     1.0             5           2.408695
# 4  75.00  0.000000       0.000000     3.0             3           2.232915
#
#    inTheMoney contractSize currency
# ...

# %%
options.puts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   contractSymbol     34 non-null     object
#  1   lastTradeDate      34 non-null     datetime64[ns, UTC]
#  2   strike             34 non-null     float64
#  3   lastPrice          34 non-null     float64
#  4   bid                34 non-null     float64
#  5   ask                34 non-null     float64
#  6   change             34 non-null     float64
#  7   percentChange      34 non-null     float64
#  8   volume             31 non-null     float64
#  9   openInterest       34 non-null     int64
#  10  impliedVolatility  34 non-null     float64
#  11  inTheMoney         34 non-null     bool
#  12  contractSize       34 non-null     object
#  13  currency           34 non-null     object
# dtypes: bool(1), datetime64[ns, UTC](1), float64(8), int64(1), object(3)
# ...

# %%
PROXY_SERVER = 'PROXY_SERVER'

msft = yf.Ticker("GOOG")

msft.history(proxy=PROXY_SERVER)
msft.get_actions(proxy=PROXY_SERVER)
msft.get_dividends(proxy=PROXY_SERVER)
msft.get_splits(proxy=PROXY_SERVER)
msft.get_balance_sheet(proxy=PROXY_SERVER)
msft.get_cashflow(proxy=PROXY_SERVER)
# Out:
# ERROR:yfinance:GOOG: No price data found, symbol may be delisted (period=1mo)
# ERROR:yfinance:GOOG: No price data found, symbol may be delisted (1d 1925-06-09 -> 2024-05-15)
# ERROR:yfinance:GOOG: No price data found, symbol may be delisted (1d 1925-06-09 -> 2024-05-15)
# ERROR:yfinance:GOOG: No price data found, symbol may be delisted (1d 1925-06-09 -> 2024-05-15)
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# # Downloading Symbol Data

# %%
symbol = 'T'
ticker = yf.Ticker(symbol)
data = yf.download("T", period="24mo")
pd.Series(ticker.info).head(20)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# address1                                            208 South Akard Street
# city                                                                Dallas
# state                                                                   TX
# zip                                                                  75202
# country                                                      United States
# phone                                                         210 821 4105
# website                                                https://www.att.com
# industry                                                  Telecom Services
# industryKey                                               telecom-services
# industryDisp                                              Telecom Services
# sector                                              Communication Services
# sectorKey                                           communication-services
# ...

# %%
print(data)
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2022-05-16  19.930000  20.379999  19.680000  20.280001  17.838423  40027000
# 2022-05-17  20.400000  20.670000  20.240000  20.570000  18.093502  42938400
# 2022-05-18  20.510000  20.629999  20.129999  20.230000  17.794437  43342800
# 2022-05-19  19.920000  20.340000  19.910000  20.209999  17.776844  41588100
# 2022-05-20  20.209999  20.420000  20.090000  20.400000  17.943970  47415800
# ...               ...        ...        ...        ...        ...       ...
# 2024-05-09  17.100000  17.190001  17.040001  17.180000  17.180000  22547700
# 2024-05-10  17.200001  17.219999  17.120001  17.170000  17.170000  19229600
# 2024-05-13  17.180000  17.340000  17.150000  17.260000  17.260000  28014800
# 2024-05-14  17.280001  17.340000  17.219999  17.299999  17.299999  23545300
# 2024-05-15  17.350000  17.440001  17.180000  17.330000  17.330000  30842000
#
# [503 rows x 6 columns]

# %%
current_price = ticker.history(period='1d', interval='1m')

# %%
print(data['Close'][-1])
# Out:
# 17.329999923706055

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 503 entries, 2022-05-16 to 2024-05-15
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       503 non-null    float64
#  1   High       503 non-null    float64
#  2   Low        503 non-null    float64
#  3   Close      503 non-null    float64
#  4   Adj Close  503 non-null    float64
#  5   Volume     503 non-null    int64
# dtypes: float64(5), int64(1)
# memory usage: 27.5 KB

# %% [markdown]
# # Downloading Multiple Symbols Data

# %%
tickers = yf.Tickers('gme nflx goog')

# %%
tickers
# Out:
# yfinance.Tickers object <GME,NFLX,GOOG>

# %%
pd.Series(tickers.tickers['GME'].info).head(20)
# Out:
# address1                                              625 Westport Parkway
# city                                                             Grapevine
# state                                                                   TX
# zip                                                                  76051
# country                                                      United States
# phone                                                         817 424 2000
# website                                           https://www.gamestop.com
# industry                                                  Specialty Retail
# industryKey                                               specialty-retail
# industryDisp                                              Specialty Retail
# sector                                                   Consumer Cyclical
# sectorKey                                                consumer-cyclical
# ...

# %%
tickers.tickers['NFLX'].history(period="4mo")
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2024-01-16 00:00:00-05:00  490.000000  494.149994  478.019989  481.239990
# 2024-01-17 00:00:00-05:00  484.500000  486.209991  475.260010  480.329987
# 2024-01-18 00:00:00-05:00  480.029999  485.769989  478.019989  485.309998
# 2024-01-19 00:00:00-05:00  484.980011  485.670013  476.059998  482.950012
# 2024-01-22 00:00:00-05:00  487.549988  489.799988  479.899994  485.709991
# ...                               ...         ...         ...         ...
# 2024-05-09 00:00:00-04:00  614.400024  615.719971  605.750000  612.090027
# 2024-05-10 00:00:00-04:00  619.000000  623.979980  605.059998  610.869995
# 2024-05-13 00:00:00-04:00  614.299988  618.219971  606.830017  616.590027
# 2024-05-14 00:00:00-04:00  615.169983  621.479980  608.400024  613.659973
# 2024-05-15 00:00:00-04:00  618.570007  624.099976  609.099976  613.520020
#
#                             Volume  Dividends  Stock Splits
# Date
# ...

# %%
from matplotlib import pyplot as plt
_df_7.plot(kind='scatter', x='Close', y='Volume', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
tickers.history(period='1mo').stack(-1)
# Out:
# [*********************100%%**********************]  3 of 3 completed
# Price                   Close  Dividends        High         Low        Open  \
# Date       Ticker
# 2024-04-16 GME      10.370000        0.0   10.550000    9.950000   10.000000
#            GOOG    156.000000        0.0  157.229996  155.050003  155.639999
#            NFLX    617.520020        0.0  622.450012  607.500000  607.500000
# 2024-04-17 GME      10.300000        0.0   10.590000   10.300000   10.440000
#            GOOG    156.880005        0.0  158.681000  156.134995  157.190002
# ...                       ...        ...         ...         ...         ...
# 2024-05-14 GOOG    171.929993        0.0  172.779999  170.419998  171.589996
#            NFLX    613.659973        0.0  621.479980  608.400024  615.169983
# 2024-05-15 GME      39.549999        0.0   42.349998   31.000000   40.310001
#            GOOG    173.880005        0.0  174.046005  172.029999  172.300003
# ...

# %%
data = yf.download("GME NFLX GOOG", start="2020-5-15", end="2024-05-15")
# Out:
# [*********************100%%**********************]  3 of 3 completed

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1006 entries, 2020-05-15 to 2024-05-14
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Adj Close, GME)   1006 non-null   float64
#  1   (Adj Close, GOOG)  1006 non-null   float64
#  2   (Adj Close, NFLX)  1006 non-null   float64
#  3   (Close, GME)       1006 non-null   float64
#  4   (Close, GOOG)      1006 non-null   float64
#  5   (Close, NFLX)      1006 non-null   float64
#  6   (High, GME)        1006 non-null   float64
#  7   (High, GOOG)       1006 non-null   float64
#  8   (High, NFLX)       1006 non-null   float64
#  9   (Low, GME)         1006 non-null   float64
#  10  (Low, GOOG)        1006 non-null   float64
#  11  (Low, NFLX)        1006 non-null   float64
#  12  (Open, GME)        1006 non-null   float64
#  13  (Open, GOOG)       1006 non-null   float64
#  14  (Open, NFLX)       1006 non-null   float64
# ...

# %%
data = yf.download(
        tickers = "GME NFLX GOOG", # list or string

        # use "period" instead of start/end
        # valid periods: 1d,5d,1mo,3mo,6mo,1y,2y,5y,10y,ytd,max
        # (optional, default is '1mo')
        period = "5d",

        # fetch data by interval (including intraday if period < 60 days)
        # valid intervals: 1m,2m,5m,15m,30m,60m,90m,1h,1d,5d,1wk,1mo,3mo
        # (optional, default is '1d')
        interval = "1m",

        # group by ticker (to access via data['SPY'])
        # (optional, default is 'column')
        group_by = 'ticker',

        # adjust all OHLC automatically
        # (optional, default is False)
        auto_adjust = True,

        # download pre/post regular market hours data
        # (optional, default is False)
        prepost = True,

        # use threads for mass downloading? (True/False/Integer)
        # (optional, default is True)
        threads = True,

        # proxy URL scheme use use when downloading?
        # (optional, default is None)
        proxy = None
    )
# Out:
# [*********************100%%**********************]  3 of 3 completed

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4687 entries, 2024-05-09 04:00:00-04:00 to 2024-05-15 19:59:57-04:00
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   (GME, Open)     4380 non-null   float64
#  1   (GME, High)     4380 non-null   float64
#  2   (GME, Low)      4380 non-null   float64
#  3   (GME, Close)    4380 non-null   float64
#  4   (GME, Volume)   4380 non-null   float64
#  5   (GOOG, Open)    3965 non-null   float64
#  6   (GOOG, High)    3965 non-null   float64
#  7   (GOOG, Low)     3965 non-null   float64
#  8   (GOOG, Close)   3965 non-null   float64
#  9   (GOOG, Volume)  3965 non-null   float64
#  10  (NFLX, Open)    3536 non-null   float64
#  11  (NFLX, High)    3536 non-null   float64
#  12  (NFLX, Low)     3536 non-null   float64
#  13  (NFLX, Close)   3536 non-null   float64
#  14  (NFLX, Volume)  3536 non-null   float64
# dtypes: float64(15)
# ...

# %%
from pandas_datareader import data as pdr

import yfinance as yf
yf.pdr_override()

# download dataframe
data = pdr.get_data_yahoo('GME NFLX GOOG',
                          start='2020-5-15',
                          end='2024-5-15',
                          auto_adjust=False)
# Out:
# [*********************100%%**********************]  3 of 3 completed

# %%
# auto_adjust = True
data.tail()
# Out:
# Price       Adj Close                              Close              \
# Ticker            GME        GOOG        NFLX        GME        GOOG
# Date
# 2024-05-08  15.920000  171.160004  609.469971  15.920000  171.160004
# 2024-05-09  18.010000  171.580002  612.090027  18.010000  171.580002
# 2024-05-10  17.459999  170.289993  610.869995  17.459999  170.289993
# 2024-05-13  30.450001  170.899994  616.590027  30.450001  170.899994
# 2024-05-14  48.750000  171.929993  613.659973  48.750000  171.929993
#
# Price                        High                                Low  \
# Ticker            NFLX        GME        GOOG        NFLX        GME
# Date
# 2024-05-08  609.469971  17.240000  171.908997  618.219971  15.330000
# 2024-05-09  612.090027  18.510000  172.440002  615.719971  15.350000
# 2024-05-10  610.869995  20.200001  171.339996  623.979980  16.879999
# 2024-05-13  616.590027  38.200001  170.949997  618.219971  24.770000
# ...

# %%
# auto_adjust = False
data.tail()
# Out:
# Price       Adj Close                              Close              \
# Ticker            GME        GOOG        NFLX        GME        GOOG
# Date
# 2024-05-08  15.920000  171.160004  609.469971  15.920000  171.160004
# 2024-05-09  18.010000  171.580002  612.090027  18.010000  171.580002
# 2024-05-10  17.459999  170.289993  610.869995  17.459999  170.289993
# 2024-05-13  30.450001  170.899994  616.590027  30.450001  170.899994
# 2024-05-14  48.750000  171.929993  613.659973  48.750000  171.929993
#
# Price                        High                                Low  \
# Ticker            NFLX        GME        GOOG        NFLX        GME
# Date
# 2024-05-08  609.469971  17.240000  171.908997  618.219971  15.330000
# 2024-05-09  612.090027  18.510000  172.440002  615.719971  15.350000
# 2024-05-10  610.869995  20.200001  171.339996  623.979980  16.879999
# 2024-05-13  616.590027  38.200001  170.949997  618.219971  24.770000
# ...
