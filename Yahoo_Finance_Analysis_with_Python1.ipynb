# %% [markdown]
# <a href="https://colab.research.google.com/github/arand013/FinancialModeling/blob/main/Yahoo_Finance_Analysis_with_Python1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Yahoo Finance Analysis with Python

# %%
# !pip install yfinance
import yfinance as yf

ticker = "AAPL"
start_date = "2020-05-14"
end_date = "2024-05-14"

df = yf.download(ticker, start=start_date, end=end_date)
# Out:
# ...
# [*********************100%%**********************]  1 of 1 completed

# %%
# import Libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2020-05-14  76.127502  77.447502  75.382500  77.385002  75.575356  158929200
# 2020-05-15  75.087502  76.974998  75.052498  76.927498  75.128563  166348400
# 2020-05-18  78.292503  79.125000  77.580002  78.739998  76.898674  135178400
# 2020-05-19  78.757500  79.629997  78.252502  78.285004  76.454330  101729600
# 2020-05-20  79.169998  79.879997  79.129997  79.807503  77.941223  111504800
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Open'].plot(kind='hist', bins=20, title='Open')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['High'].plot(kind='hist', bins=20, title='High')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ...

# %%
from matplotlib import pyplot as plt
_df_15['Close'].plot(kind='line', figsize=(8, 4), title='Close')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
df.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-05-07  183.449997  184.899994  181.320007  182.399994  182.152924
# 2024-05-08  182.850006  183.070007  181.449997  182.740005  182.492477
# 2024-05-09  182.559998  184.660004  182.110001  184.570007  184.320007
# 2024-05-10  184.899994  185.089996  182.130005  183.050003  183.050003
# 2024-05-13  185.440002  187.100006  184.619995  186.279999  186.279999
#
#               Volume
# Date
# 2024-05-07  77305800
# 2024-05-08  45057100
# 2024-05-09  48983000
# 2024-05-10  50759500
# 2024-05-13  72044800

# %%
df.shape
# Out:
# (1006, 6)

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1006.000000  1006.000000  1006.000000  1006.000000  1006.000000
# mean    150.418547   152.079540   148.839200   150.527570   148.892573
# std      26.861914    26.909641    26.840954    26.878533    27.359728
# min      75.087502    76.974998    75.052498    76.927498    75.128563
# 25%     132.049995   133.522495   130.255005   131.962505   129.608837
# 50%     150.055000   151.570007   148.584999   150.529999   148.808571
# 75%     172.290001   173.887497   170.834999   172.607498   171.273853
# max     198.020004   199.619995   197.000000   198.110001   197.589523
#
#              Volume
# count  1.006000e+03
# mean   8.780566e+07
# std    4.180905e+07
# min    2.404830e+07
# 25%    5.920308e+07
# 50%    7.738550e+07
# 75%    1.032626e+08
# max    3.743368e+08

# %%
# Overview of closing price before calculating DMAs
sns.set_style('darkgrid')
plt.figure(figsize = (7,5), dpi = 100)
plt.title('Closing Price')
plt.plot(df['Close'])

# %%
# Calculate 50DMA
df['fiftyDMA'] = df['Close'].rolling(50).mean()

# %%
# Calculate 200DMA
df['thDMA'] = df['Close'].rolling(200).mean()

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1006.000000  1006.000000  1006.000000  1006.000000  1006.000000
# mean    150.418547   152.079540   148.839200   150.527570   148.892573
# std      26.861914    26.909641    26.840954    26.878533    27.359728
# min      75.087502    76.974998    75.052498    76.927498    75.128563
# 25%     132.049995   133.522495   130.255005   131.962505   129.608837
# 50%     150.055000   151.570007   148.584999   150.529999   148.808571
# 75%     172.290001   173.887497   170.834999   172.607498   171.273853
# max     198.020004   199.619995   197.000000   198.110001   197.589523
#
#              Volume    fiftyDMA       thDMA
# count  1.006000e+03  957.000000  807.000000
# mean   8.780566e+07  151.637183  152.633547
# std    4.180905e+07   23.992798   17.931458
# min    2.404830e+07   87.733550  113.028725
# 25%    5.920308e+07  131.859800  140.830500
# 50%    7.738550e+07  149.802000  153.967950
# ...

# %%
# Plot Closing Price vs 50DMA vs 200DMA
sns.set_style('darkgrid')
plt.figure(figsize = (7,5), dpi = 100)
plt.title('Closing Price vs 50DMA vs 200DMA')
plt.plot(df['Close'], label = 'Close')
plt.plot(df['fiftyDMA'], label = '50DMA')
plt.plot(df['thDMA'], label = '200DMA')
plt.legend()

# %% [markdown]
# # Finding the possible futuristic movement of the stock

# %%
# Analyzing correlation between each variables
plt.figure(figsize=(7,7), dpi=100)
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %%
# Plot Distplot of 50DMA
sns.set_style('darkgrid')
plt.figure(figsize = (7,5), dpi = 100)
plt.title('Distplot of 50DMA')
sns.distplot(df['fiftyDMA'])
# Out:
# <Axes: title={'center': 'Distplot of 50DMA'}, xlabel='fiftyDMA', ylabel='Density'>

# %%
# Plot Distplot of the close price
sns.set_style('darkgrid')
plt.figure(figsize = (7,5), dpi = 100)
plt.title('Distplot of the close price')
sns.distplot(df['Close'])
# Out:
# <Axes: title={'center': 'Distplot of the close price'}, xlabel='Close', ylabel='Density'>

# %%
# Import library for Statsmodels Formula(SMF)
import statsmodels.formula.api as smf

# %%
model = smf.ols(formula = 'Close~fiftyDMA', data = df)
model = model.fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Close   R-squared:                       0.837
# Model:                            OLS   Adj. R-squared:                  0.837
# Method:                 Least Squares   F-statistic:                     4916.
# Date:                Thu, 16 May 2024   Prob (F-statistic):               0.00
# Time:                        01:27:29   Log-Likelihood:                -3502.5
# No. Observations:                 957   AIC:                             7009.
# Df Residuals:                     955   BIC:                             7019.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     18.8495      1.948      9.677      0.000      15.027      22.672
# ...

# %%
sns.set_style('darkgrid')
plt.figure(figsize = (7,5), dpi = 100)
plt.title('Closing Price vs 50DMA vs 200DMA')
plt.plot(df['Close'], label = 'Close')
plt.plot(df['fiftyDMA'], label = '50DMA')
plt.plot(df['thDMA'], label = '200DMA')
plt.legend()
